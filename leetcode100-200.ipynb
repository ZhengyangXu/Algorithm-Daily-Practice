# %%
#
# @lc app=leetcode.cn id=127 lang=python3
#
# [127] 单词接龙
#
# https://leetcode-cn.com/problems/word-ladder/description/
#
# algorithms
# Medium (45.45%)
# Likes:    655
# Dislikes: 0
# Total Accepted:    89.4K
# Total Submissions: 196.7K
# Testcase Example:  '"hit"\n"cog"\n["hot","dot","dog","lot","log","cog"]'
#
# 给定两个单词（beginWord 和 endWord）和一个字典，找到从 beginWord 到 endWord
# 的最短转换序列的长度。转换需遵循如下规则：
# 
# 
# 每次转换只能改变一个字母。
# 转换过程中的中间单词必须是字典中的单词。
# 
# 
# 说明:
# 
# 
# 如果不存在这样的转换序列，返回 0。
# 所有单词具有相同的长度。
# 所有单词只由小写字母组成。
# 字典中不存在重复的单词。
# 你可以假设 beginWord 和 endWord 是非空的，且二者不相同。
# 
# 
# 示例 1:
# 
# 输入:
# beginWord = "hit",
# endWord = "cog",
# wordList = ["hot","dot","dog","lot","log","cog"]
# 
# 输出: 5
# 
# 解释: 一个最短转换序列是 "hit" -> "hot" -> "dot" -> "dog" -> "cog",
# ⁠    返回它的长度 5。
# 
# 
# 示例 2:
# 
# 输入:
# beginWord = "hit"
# endWord = "cog"
# wordList = ["hot","dot","dog","lot","log"]
# 
# 输出: 0
# 
# 解释: endWord "cog" 不在字典中，所以无法进行转换。
# 
#
def ladderLength(beginWord, endWord, wordList):
        if endWord not in wordList:
            return 0 
        def isValid(w,word):
            
            count = 0 
            if len(w) != len(word):
                return False 
            for i in range(len(w)): 
                if w[i] != word[i]:
                    count += 1 
            if count == 1:
                return True 
            return False 
        
        def dfs(beginWord,path):
            if beginWord == endWord:
                path = path[:]
                res.append(path)
                
            
            for word in wordList:
                if not isValid(beginWord,word):
                    continue 
                path.add(word)
                print(path)
                dfs(word,path)
                path.remove(word)

                    
        res = []
        path = set()
        dfs(beginWord,path)
        return min(res)

# %%
beginWord="hit"
endWord="cog"
WordList=["hot","dot","dog","lot","log","cog"]

# %%
ladderLength(beginWord,endWord,WordList)
# Out:
# ot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# {'hot', 'dot'}
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-30-62536a64289c> in <module>
# ----> 1 ladderLength(beginWord,endWord,WordList)
#
# <ipython-input-28-29e2184f8845> in ladderLength(beginWord, endWord, wordList)
#      89         res = []
#      90         path = set()
# ---> 91         dfs(beginWord,path)
#      92         return min(res)
#
# <ipython-input-28-29e2184f8845> in dfs(beginWord, path)
#      83                 path.add(word)
#      84                 print(path)
# ---> 85                 dfs(word,path)
#      86                 path.remove(word)
#      87
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-28-29e2184f8845> in dfs(beginWord, path)
#      83                 path.add(word)
#      84                 print(path)
# ---> 85                 dfs(word,path)
#      86                 path.remove(word)
#      87
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
